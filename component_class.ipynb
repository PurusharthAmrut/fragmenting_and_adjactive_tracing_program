# %%
import pandas as pd
import re

data = pd.read_csv('final_dataset3.csv')
data.head()
# Out:
#    Rating                                            Reviews  Review Votes
# 0       5  feel lucky found phone not hard phone line som...           1.0
# 1       1  already phone problems know stated but dang no...           1.0
# 2       5  guys best little situation item but quickly fi...           2.0
# 3       1  im really disappointed phone service phone wen...           1.0
# 4       5  ordered phone replacement model contract expir...           1.0

# %%
data.iloc[0]
# Out:
# Rating                                                          5
# Reviews         feel lucky found phone not hard phone line som...
# Review Votes                                                    1
# Name: 0, dtype: object

# %%
category_tags = []

# %%
for review in sample['Reviews']:
    match = re.search(r'\bcamera\b|\bbattery\b',review,flags=re.I)
    if match is not None:
        category_tags.append(match.group())
    else:
        category_tags.append('')
print('done!')
# Out:
# done!

# %%
sample.insert()
# Out:
# C:\Users\Puru\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sample.insert(3,"Category",category_tags,True)

# %%
sample.head(50)
# Out:
#     Rating                                            Reviews  Review Votes  \
# 0        5  feel lucky found used phone us  not used hard ...           1.0
# 1        1  already phone problems know stated used but da...           1.0
# 2        5  guys best little situation item but quickly fi...           2.0
# 3        1  im really disappointed phone service phone wen...           1.0
# 4        5  ordered phone replacement model contract expir...           1.0
# 5        5  able get phone previously ownedwith keyboard t...           6.0
# 6        4  love phone everything need works great purchas...           1.0
# 7        1  purchased phone december christmas present cal...          19.0
# 8        5  bought alternative smart phone data plan use g...           1.0
# 9        5  used unlocked gsm nokia asha 302 philippines j...           1.0
# 10       5  nokia brand can used telephone good price exce...           1.0
# ...
